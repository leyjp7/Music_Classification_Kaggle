# %%
#!pip install seaborn
#!pip install librosa
#!pip install scikit-image
#!pip install datasets

# %%
#!pip install kaggle

# %%
#!ls

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import os as os
import tensorflow as tf
import time

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import StratifiedKFold


from joblib import delayed, Parallel
from tqdm import tqdm


import librosa
import librosa.display
import IPython.display as ipd
import skimage.io

from itertools import cycle

sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip [ZIP FILE NAME . zip] [Location of Folder to ZIP]
#!zip -r processed_train.zip /content/drive/MyDrive/Colab_Nb/data/processed_train

# %%
# !zip [ZIP FILE NAME . zip] [Location of Folder to ZIP]
#!zip -r kaggle-pog-series-s01e02.zip  /content/drive/MyDrive/Colab_Nb/data/kaggle-pog-series-s01e02

# %%
# !mkdir /content/drive/MyDrive/Colab_Nb/data/

# %%
# !mkdir /content/unzip_data

# %%
#!unzip -d /content/drive/MyDrive/Colab_Nb/data/ /content/drive/MyDrive/Colab_Nb/kaggle-pog-series-s01e02.zip

# %%
#!7z e /content/drive/MyDrive/Colab_Nb/data/kaggle-pog-series-s01e02.zip -o/content/drive/MyDrive/Colab_Nb/data/

# %%
# move back to location where we want to extract the zip file in colab temp drive
# !cd [Location of colab drive]
# !cd /content/unzip_data

# %%
#!7z e /content/processed_train.zip -o/content/unzip_data/

# %%
#!ls

# %% [markdown]
# Loading training and testing CSV datasets

# %%
# Defining variables

NUM_MEL_SPECS = 1

class DataPath:
    def __init__(self, data, audio_path, process, processed_train, processed_test):
        self.data = data
        self.audio = audio_path
        self.process = process
        self.protrain = processed_train
        self.protest =  processed_test



DATA_PATH = "/content/drive/MyDrive/Colab_Nb/data/"
AUDIO_PATH = DATA_PATH + "train/"
PROCESSED_TRAIN_DATA = "/content/drive/MyDrive/Colab_Nb/data/processed_train/"
PROCESSED_TEST_DATA = "/content/drive/MyDrive/Colab_Nb/data/processed_test/"

PATH = DataPath(DATA_PATH, AUDIO_PATH, 'data/processed/', PROCESSED_TRAIN_DATA, PROCESSED_TEST_DATA)

TRAIN_ERA = 2
MODEL_NAME = 'music_genre.keras'
MODEL_PATH = '/content/drive/MyDrive/Colab_Nb/models'

BATCH_SIZE = 32
lot = 1    # multiple of 19_000 // 500
img_width, img_height, img_num_channels = 256, 938, 1
loss_function = categorical_crossentropy
nb_classes = 19
nb_epochs = 10
optimizer = Adam()
verbosity = 1
shuffle = True

# Determine shape of the data
input_shape = (img_width, img_height, img_num_channels)

# %%
# load metadata into pandas dataframes

df_known = pd.read_csv(PATH.data + 'train.csv')
#df_test = pd.read_csv('data/kaggle-pog-series-s01e02/test.csv')
#submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/kaggle-pog-series-s01e02/sample_submission.csv')
df_known
# Out:
#        song_id    filename          filepath  genre_id                genre
# 0        10150  010150.ogg  train/010150.ogg         7         Instrumental
# 1         7358  007358.ogg  train/007358.ogg         2                 Punk
# 2        20573  020573.ogg  train/020573.ogg         5                 Folk
# 3        11170  011170.ogg  train/011170.ogg        12  Old-Time / Historic
# 4        16662  016662.ogg  train/016662.ogg         1                 Rock
# ...        ...         ...               ...       ...                  ...
# 19917     9337  009337.ogg  train/009337.ogg         0           Electronic
# 19918     8340  008340.ogg  train/008340.ogg         4              Hip-Hop
# 19919    16248  016248.ogg  train/016248.ogg         4              Hip-Hop
# 19920    11875  011875.ogg  train/011875.ogg         2                 Punk
# 19921     6579  006579.ogg  train/006579.ogg         1                 Rock
#
# [19922 rows x 5 columns]

# %%
#remove rows from dataframe that don't exist as an audio file

df_known = df_known[[os.path.isfile(PATH.data + i) for i in df_known['filepath']]]
#df_test = df_test[[os.path.isfile('data/kaggle-pog-series-s01e02/'+i) for i in df_test['filepath']]]

df_known
# Out:
#        song_id    filename          filepath  genre_id                genre
# 0        10150  010150.ogg  train/010150.ogg         7         Instrumental
# 1         7358  007358.ogg  train/007358.ogg         2                 Punk
# 2        20573  020573.ogg  train/020573.ogg         5                 Folk
# 3        11170  011170.ogg  train/011170.ogg        12  Old-Time / Historic
# 4        16662  016662.ogg  train/016662.ogg         1                 Rock
# ...        ...         ...               ...       ...                  ...
# 19917     9337  009337.ogg  train/009337.ogg         0           Electronic
# 19918     8340  008340.ogg  train/008340.ogg         4              Hip-Hop
# 19919    16248  016248.ogg  train/016248.ogg         4              Hip-Hop
# 19920    11875  011875.ogg  train/011875.ogg         2                 Punk
# 19921     6579  006579.ogg  train/006579.ogg         1                 Rock
#
# [19909 rows x 5 columns]

# %%
# create directories to store processed data
def create_processing_dirs():
    if not os.path.isdir(PATH.protrain):
        os.mkdir(PATH.protrain)
    if not os.path.isdir(PATH.protest):
        os.mkdir(PATH.protest)

# %%
# function to load audio file and resample it
def load_ogg_16k_mono(filename):
    # Load encoded ogg file

    # Decode ogg file
    y, sr = librosa.load(filename)
    #convert all files to mono (if not already)
    y = librosa.to_mono(y)
    # Goes to 16000hz - reduced sample rate within human hearing
    y = librosa.resample(y, orig_sr=sr, target_sr=16000)
    return y

# %% [markdown]
# Extracting waveform array data and sample rate for the first training audio file

# %% [markdown]
# Plotting raw waveform

# %%
create_processing_dirs()

# %%
def preprocess1(file_name, dest = None):
    ogg = load_ogg_16k_mono(file_name)
    ogg = ogg[:480000]
    zero_padding = np.zeros((480000) - np.shape(ogg)[0], dtype=np.float32)
    ogg = np.concatenate((zero_padding, ogg),0)
    S = librosa.feature.melspectrogram(y=ogg,sr=16000,n_mels=128 * 2,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    melnorm = librosa.util.normalize(S_db_mel)
    #skimage.io.imsave(dest + file_name, melnorm)
    file_name = file_name.split('.')[0]
    file_name = file_name.split('/')[-1]
    return np.save(PATH.protrain + 'mels/'+file_name+'.npy',melnorm)

# %%
def preprocess2(file_name, dest = None):
    ogg = load_ogg_16k_mono(file_name)
    ogg = ogg[:480000]
    zero_padding = np.zeros((480000) - np.shape(ogg)[0], dtype=np.float32)
    ogg = np.concatenate((zero_padding, ogg),0)
    S = librosa.feature.melspectrogram(y=ogg,sr=16000,n_mels=128 * 2,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    melnorm = librosa.util.normalize(S_db_mel)
    return melnorm

# %%
class CustomDataGen(tf.keras.utils.Sequence):

    def __init__(self, df, X_col, y_col,
                 batch_size,
                 input_size=input_shape,
                 shuffle=shuffle,
                 from_npy = False):

        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.batch_size = batch_size
        self.input_size = input_size
        self.shuffle = shuffle
        self.from_npy = from_npy

        self.n = len(self.df)
        self.n_type = df[y_col].nunique()

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __get_input(self, path):
      if self.from_npy == True:
        path = path.split('.')[0]
        path = path.split('/')[-1]
        melnorm = np.load(PATH.protrain + 'mels/'+path+'.npy', allow_pickle = True)
        melnorm = np.expand_dims(melnorm, -1)
        return melnorm
      else:
        ogg = load_ogg_16k_mono(PATH.data + path)
        ogg = ogg[:480000]
        zero_padding = np.zeros((480000) - np.shape(ogg)[0], dtype=np.float32)
        ogg = np.concatenate((zero_padding, ogg),0)
        S = librosa.feature.melspectrogram(y=ogg,sr=16000,n_mels=128 * 2,)
        S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
        melnorm = librosa.util.normalize(S_db_mel)
        melnorm = np.expand_dims(melnorm, -1)
        return melnorm

    def __get_output(self, label, num_classes):
        return tf.keras.utils.to_categorical(label, num_classes=nb_classes)

    def __get_data(self, batches):
        # Generates data containing batch_size samples

        path_batch = batches[self.X_col]

        type_batch = batches[self.y_col]

        X_batch = np.asarray([self.__get_input(x) for x in path_batch])

        y1_batch = np.asarray([self.__get_output(y, self.n_type) for y in type_batch])

        return X_batch, y1_batch

    def __getitem__(self, index):

        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)
        return X, y

    def __len__(self):
        return self.n // self.batch_size

# %%
df_train = df_known.iloc[1000*(TRAIN_ERA-1):1000*TRAIN_ERA,:]
#df_test = df_known.iloc[450:500,:]

# %%
delayed_preprocess = [delayed(preprocess2)(PATH.audio+path) for path in df_known.filename.values]
df_known.loc[:,'melspec'] = Parallel(n_jobs=-1, verbose=5)(delayed_preprocess)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 2162 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3026 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 3512 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 4592 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 5186 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 5816 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 6482 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 7184 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 7922 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 8696 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 9506 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 10352 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 11234 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 12152 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 13106 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 14096 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 15122 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 16184 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 17282 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 18416 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 19586 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 19909 out of 19909 | elapsed: 11.4min finished
# <ipython-input-25-f2801fca429b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_known.loc[:,'melspec'] = Parallel(n_jobs=-1, verbose=5)(delayed_preprocess)

# %%
#directory to store mel spectograms as .npy files
# !mkdir /content/drive/MyDrive/Colab_Nb/data/processed_train/mels/

# %%
delayed_preprocess = [delayed(preprocess1)(PATH.audio+path) for path in df_known.filename.values]
_ = Parallel(n_jobs=-1, verbose=5)(delayed_preprocess)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 2162 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 3026 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 3512 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 4592 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 5186 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 5816 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 6482 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 7184 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 7922 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 8696 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 9506 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 10352 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 11234 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 12152 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 13106 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 14096 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 15122 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 16184 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 17282 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 18416 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 19586 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 19909 out of 19909 | elapsed: 17.9min finished

# %%
labels = np.load('/content/drive/MyDrive/Colab_Nb/data/processed_train/labels.npy')

# %%
labels = tf.keras.utils.to_categorical(labels, 19)

# %%
#initiate data generator
gen_train = CustomDataGen(df_train, 'filepath', 'genre_id', BATCH_SIZE, from_npy = True)

# %%
X_train, y_train = gen_train[1]

# %%
print(np.shape(y_train))
# Out:
# (32, 19)

# %%
# load existing trained model or create new one
if os.path.exists(MODEL_PATH + MODEL_NAME):

  model = tf.keras.models.load_model(MODEL_PATH + MODEL_NAME)

else:

  lc0 = tf.keras.layers.Conv2D(16, (5,5), input_shape=input_shape, name='input')
  acti1 = tf.keras.layers.ELU()
  lc1 = tf.keras.layers.Dropout(.15)
  lc2 = tf.keras.layers.BatchNormalization()
  lc3 = tf.keras.layers.MaxPool2D(pool_size=(2,2),padding='same')

  lc4 = tf.keras.layers.Conv2D(32, (3,3))
  acti2 = tf.keras.layers.ELU()
  lc5 = tf.keras.layers.Dropout(.15)
  lc6 = tf.keras.layers.BatchNormalization()
  lc7 = tf.keras.layers.MaxPool2D(pool_size=(2,2),padding='same')

  lc8 = tf.keras.layers.Conv2D(64, (3,3))
  acti3 = tf.keras.layers.ELU()
  lc9 = tf.keras.layers.Dropout(.15)
  lc10 = tf.keras.layers.BatchNormalization()
  lc11 = tf.keras.layers.MaxPool2D(pool_size=(4,4),padding='same')

  lc12 = tf.keras.layers.Conv2D(128, (3,3))
  acti4 = tf.keras.layers.ELU()
  lc13 = tf.keras.layers.Dropout(.15)
  lc14 = tf.keras.layers.BatchNormalization()
  lc15 = tf.keras.layers.MaxPool2D(pool_size=(4,4),padding='same')

  rs = tf.keras.layers.Reshape((-1, 128))
  lf = tf.keras.layers.Flatten()

  gr1 = tf.keras.layers.GRU(24, return_sequences=True)
  gr2 = tf.keras.layers.GRU(24, return_sequences=False)
  gr3 = tf.keras.layers.Dropout(0.3)

  ld1 = tf.keras.layers.Dense(32, activation='relu')
  ld2 = tf.keras.layers.Dropout(.5)
  ld3 = tf.keras.layers.BatchNormalization()

  lfinal = tf.keras.layers.Dense(nb_classes, activation='softmax', name='output')

  model = tf.keras.Sequential([lc0, acti1,lc1,lc2,lc3,lc4,acti2,lc5,lc6,lc7,lc8,acti3,lc9,lc10,lc11,lc12,acti4,lc13,lc14,lc15,rs,gr1,gr2,gr3,lfinal], name="model_example")
  model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu_16 (ELU)                (None, 252, 934, 16)      0
#
#  dropout_24 (Dropout)        (None, 252, 934, 16)      0
#
#  batch_normalization_20 (Ba  (None, 252, 934, 16)      64
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 126, 467, 16)      0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 124, 465, 32)      4640
#
#  elu_17 (ELU)                (None, 124, 465, 32)      0
#
#  dropout_25 (Dropout)        (None, 124, 465, 32)      0
#
#  batch_normalization_21 (Ba  (None, 124, 465, 32)      128
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 62, 233, 32)       0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 60, 231, 64)       18496
#
#  elu_18 (ELU)                (None, 60, 231, 64)       0
#
#  dropout_26 (Dropout)        (None, 60, 231, 64)       0
#
#  batch_normalization_22 (Ba  (None, 60, 231, 64)       256
#  tchNormalization)
#
#  max_pooling2d_18 (MaxPooli  (None, 15, 58, 64)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 13, 56, 128)       73856
#
#  elu_19 (ELU)                (None, 13, 56, 128)       0
#
#  dropout_27 (Dropout)        (None, 13, 56, 128)       0
#
#  batch_normalization_23 (Ba  (None, 13, 56, 128)       512
#  tchNormalization)
#
#  max_pooling2d_19 (MaxPooli  (None, 4, 14, 128)        0
#  ng2D)
#
#  reshape_4 (Reshape)         (None, 56, 128)           0
#
#  gru_8 (GRU)                 (None, 56, 24)            11088
#
#  gru_9 (GRU)                 (None, 24)                3600
#
#  dropout_28 (Dropout)        (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________

# %%
# create directory to store trained models
# !mkdir /content/drive/MyDrive/Colab_Nb/models/

# %%
# Fit data to model
history = model.fit(gen_train,
              batch_size=BATCH_SIZE,
              epochs=nb_epochs,
              verbose=verbosity)

# Generate generalization metrics
#scores = model.evaluate(tf.gather(inputs, test), tf.gather(targets, test), verbose=0)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 773s 25s/step - loss: 0.5206 - accuracy: 0.0766
# Epoch 2/10
# 31/31 [==============================] - 14s 438ms/step - loss: 0.3546 - accuracy: 0.0948
# Epoch 3/10
# 31/31 [==============================] - 11s 339ms/step - loss: 0.2656 - accuracy: 0.0897
# Epoch 4/10
# 31/31 [==============================] - 11s 340ms/step - loss: 0.2324 - accuracy: 0.1129
# Epoch 5/10
# 31/31 [==============================] - 11s 340ms/step - loss: 0.2160 - accuracy: 0.0978
# Epoch 6/10
# 31/31 [==============================] - 11s 340ms/step - loss: 0.2088 - accuracy: 0.1361
# Epoch 7/10
# 31/31 [==============================] - 11s 341ms/step - loss: 0.2029 - accuracy: 0.1562
# Epoch 8/10
# 31/31 [==============================] - 11s 342ms/step - loss: 0.2007 - accuracy: 0.1331
# Epoch 9/10
# 31/31 [==============================] - 11s 343ms/step - loss: 0.1989 - accuracy: 0.1502
# Epoch 10/10
# 31/31 [==============================] - 11s 344ms/step - loss: 0.1961 - accuracy: 0.1502

# %%
model.save('/content/drive/MyDrive/Colab_Nb/models/music_genre.keras')

# %%
inputs = X_train
targets = y_train

# %%
# Define the K-fold Cross Validator
kfold = StratifiedKFold(n_splits=5, shuffle=True)

acc_per_fold = []
loss_per_fold = []

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets.argmax(1)):

  # Define the model architecture
  model = tf.keras.Sequential([lc0, acti1,lc1,lc2,lc3,
                               lc4,acti2,lc5,lc6,lc7,
                               lc8,acti3,lc9,lc10,lc11,
                               lc12,acti4,lc13,lc14,lc15,
                               rs,gr1,gr2,gr3,lfinal],
                                name="model_example")


  # Compile the model
  model.compile(loss=loss_function,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                metrics=['accuracy'])
  model.summary()


  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  history = model.fit(tf.gather(inputs, train), tf.gather(targets, train),
              batch_size=BATCH_SIZE,
              epochs=nb_epochs,
              verbose=verbosity)

  # Generate generalization metrics
  scores = model.evaluate(tf.gather(inputs, test), tf.gather(targets, test), verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])



  # Increase fold number
  fold_no = fold_no + 1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu (ELU)                   (None, 252, 934, 16)      0
#
#  dropout (Dropout)           (None, 252, 934, 16)      0
#
#  batch_normalization (Batch  (None, 252, 934, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 126, 467, 16)      0
#  D)
#
#  conv2d (Conv2D)             (None, 124, 465, 32)      4640
#
#  elu_1 (ELU)                 (None, 124, 465, 32)      0
#
#  dropout_1 (Dropout)         (None, 124, 465, 32)      0
#
#  batch_normalization_1 (Bat  (None, 124, 465, 32)      128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 233, 32)       0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 60, 231, 64)       18496
#
#  elu_2 (ELU)                 (None, 60, 231, 64)       0
#
#  dropout_2 (Dropout)         (None, 60, 231, 64)       0
#
#  batch_normalization_2 (Bat  (None, 60, 231, 64)       256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 58, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 56, 128)       73856
#
#  elu_3 (ELU)                 (None, 13, 56, 128)       0
#
#  dropout_3 (Dropout)         (None, 13, 56, 128)       0
#
#  batch_normalization_3 (Bat  (None, 13, 56, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 14, 128)        0
#  g2D)
#
#  reshape (Reshape)           (None, 56, 128)           0
#
#  gru (GRU)                   (None, 56, 24)            11088
#
#  gru_1 (GRU)                 (None, 24)                3600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/10
# 13/13 [==============================] - 24s 511ms/step - loss: 2.8526 - accuracy: 0.1000
# Epoch 2/10
# 13/13 [==============================] - 4s 333ms/step - loss: 2.7313 - accuracy: 0.1050
# Epoch 3/10
# 13/13 [==============================] - 4s 339ms/step - loss: 2.6678 - accuracy: 0.1725
# Epoch 4/10
# 13/13 [==============================] - 5s 347ms/step - loss: 2.6245 - accuracy: 0.1500
# Epoch 5/10
# 13/13 [==============================] - 5s 350ms/step - loss: 2.6509 - accuracy: 0.1625
# Epoch 6/10
# 13/13 [==============================] - 4s 338ms/step - loss: 2.5925 - accuracy: 0.2075
# Epoch 7/10
# 13/13 [==============================] - 4s 335ms/step - loss: 2.5832 - accuracy: 0.1850
# Epoch 8/10
# 13/13 [==============================] - 4s 335ms/step - loss: 2.5303 - accuracy: 0.2025
# Epoch 9/10
# 13/13 [==============================] - 4s 345ms/step - loss: 2.5448 - accuracy: 0.1800
# Epoch 10/10
# 13/13 [==============================] - 5s 346ms/step - loss: 2.5099 - accuracy: 0.2050
# Score for fold 1: loss of 2.8474016189575195; accuracy of 14.000000059604645%
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu (ELU)                   (None, 252, 934, 16)      0
#
#  dropout (Dropout)           (None, 252, 934, 16)      0
#
#  batch_normalization (Batch  (None, 252, 934, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 126, 467, 16)      0
#  D)
#
#  conv2d (Conv2D)             (None, 124, 465, 32)      4640
#
#  elu_1 (ELU)                 (None, 124, 465, 32)      0
#
#  dropout_1 (Dropout)         (None, 124, 465, 32)      0
#
#  batch_normalization_1 (Bat  (None, 124, 465, 32)      128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 233, 32)       0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 60, 231, 64)       18496
#
#  elu_2 (ELU)                 (None, 60, 231, 64)       0
#
#  dropout_2 (Dropout)         (None, 60, 231, 64)       0
#
#  batch_normalization_2 (Bat  (None, 60, 231, 64)       256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 58, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 56, 128)       73856
#
#  elu_3 (ELU)                 (None, 13, 56, 128)       0
#
#  dropout_3 (Dropout)         (None, 13, 56, 128)       0
#
#  batch_normalization_3 (Bat  (None, 13, 56, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 14, 128)        0
#  g2D)
#
#  reshape (Reshape)           (None, 56, 128)           0
#
#  gru (GRU)                   (None, 56, 24)            11088
#
#  gru_1 (GRU)                 (None, 24)                3600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/10
# 13/13 [==============================] - 10s 333ms/step - loss: 2.4500 - accuracy: 0.2100
# Epoch 2/10
# 13/13 [==============================] - 4s 339ms/step - loss: 2.4436 - accuracy: 0.2225
# Epoch 3/10
# 13/13 [==============================] - 5s 347ms/step - loss: 2.3848 - accuracy: 0.2425
# Epoch 4/10
# 13/13 [==============================] - 4s 346ms/step - loss: 2.3632 - accuracy: 0.2575
# Epoch 5/10
# 13/13 [==============================] - 4s 336ms/step - loss: 2.3454 - accuracy: 0.2500
# Epoch 6/10
# 13/13 [==============================] - 4s 335ms/step - loss: 2.3100 - accuracy: 0.2650
# Epoch 7/10
# 13/13 [==============================] - 4s 339ms/step - loss: 2.2539 - accuracy: 0.2700
# Epoch 8/10
# 13/13 [==============================] - 4s 345ms/step - loss: 2.2741 - accuracy: 0.2575
# Epoch 9/10
# 13/13 [==============================] - 5s 350ms/step - loss: 2.2316 - accuracy: 0.2850
# Epoch 10/10
# 13/13 [==============================] - 5s 344ms/step - loss: 2.2129 - accuracy: 0.2700
# Score for fold 2: loss of 2.9830520153045654; accuracy of 12.999999523162842%
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu (ELU)                   (None, 252, 934, 16)      0
#
#  dropout (Dropout)           (None, 252, 934, 16)      0
#
#  batch_normalization (Batch  (None, 252, 934, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 126, 467, 16)      0
#  D)
#
#  conv2d (Conv2D)             (None, 124, 465, 32)      4640
#
#  elu_1 (ELU)                 (None, 124, 465, 32)      0
#
#  dropout_1 (Dropout)         (None, 124, 465, 32)      0
#
#  batch_normalization_1 (Bat  (None, 124, 465, 32)      128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 233, 32)       0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 60, 231, 64)       18496
#
#  elu_2 (ELU)                 (None, 60, 231, 64)       0
#
#  dropout_2 (Dropout)         (None, 60, 231, 64)       0
#
#  batch_normalization_2 (Bat  (None, 60, 231, 64)       256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 58, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 56, 128)       73856
#
#  elu_3 (ELU)                 (None, 13, 56, 128)       0
#
#  dropout_3 (Dropout)         (None, 13, 56, 128)       0
#
#  batch_normalization_3 (Bat  (None, 13, 56, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 14, 128)        0
#  g2D)
#
#  reshape (Reshape)           (None, 56, 128)           0
#
#  gru (GRU)                   (None, 56, 24)            11088
#
#  gru_1 (GRU)                 (None, 24)                3600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/10
# 13/13 [==============================] - 10s 334ms/step - loss: 2.2370 - accuracy: 0.2875
# Epoch 2/10
# 13/13 [==============================] - 4s 340ms/step - loss: 2.1694 - accuracy: 0.2875
# Epoch 3/10
# 13/13 [==============================] - 5s 347ms/step - loss: 2.1746 - accuracy: 0.2875
# Epoch 4/10
# 13/13 [==============================] - 5s 347ms/step - loss: 2.1212 - accuracy: 0.3150
# Epoch 5/10
# 13/13 [==============================] - 4s 339ms/step - loss: 2.0624 - accuracy: 0.3375
# Epoch 6/10
# 13/13 [==============================] - 4s 334ms/step - loss: 2.0580 - accuracy: 0.3475
# Epoch 7/10
# 13/13 [==============================] - 4s 337ms/step - loss: 2.0541 - accuracy: 0.3025
# Epoch 8/10
# 13/13 [==============================] - 5s 346ms/step - loss: 2.0276 - accuracy: 0.3225
# Epoch 9/10
# 13/13 [==============================] - 5s 351ms/step - loss: 2.0113 - accuracy: 0.3425
# Epoch 10/10
# 13/13 [==============================] - 4s 343ms/step - loss: 1.9670 - accuracy: 0.3475
# Score for fold 3: loss of 3.244926691055298; accuracy of 12.999999523162842%
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu (ELU)                   (None, 252, 934, 16)      0
#
#  dropout (Dropout)           (None, 252, 934, 16)      0
#
#  batch_normalization (Batch  (None, 252, 934, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 126, 467, 16)      0
#  D)
#
#  conv2d (Conv2D)             (None, 124, 465, 32)      4640
#
#  elu_1 (ELU)                 (None, 124, 465, 32)      0
#
#  dropout_1 (Dropout)         (None, 124, 465, 32)      0
#
#  batch_normalization_1 (Bat  (None, 124, 465, 32)      128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 233, 32)       0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 60, 231, 64)       18496
#
#  elu_2 (ELU)                 (None, 60, 231, 64)       0
#
#  dropout_2 (Dropout)         (None, 60, 231, 64)       0
#
#  batch_normalization_2 (Bat  (None, 60, 231, 64)       256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 58, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 56, 128)       73856
#
#  elu_3 (ELU)                 (None, 13, 56, 128)       0
#
#  dropout_3 (Dropout)         (None, 13, 56, 128)       0
#
#  batch_normalization_3 (Bat  (None, 13, 56, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 14, 128)        0
#  g2D)
#
#  reshape (Reshape)           (None, 56, 128)           0
#
#  gru (GRU)                   (None, 56, 24)            11088
#
#  gru_1 (GRU)                 (None, 24)                3600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/10
# 13/13 [==============================] - 11s 333ms/step - loss: 2.0625 - accuracy: 0.3425
# Epoch 2/10
# 13/13 [==============================] - 4s 341ms/step - loss: 1.9710 - accuracy: 0.3500
# Epoch 3/10
# 13/13 [==============================] - 5s 347ms/step - loss: 1.9470 - accuracy: 0.3775
# Epoch 4/10
# 13/13 [==============================] - 5s 350ms/step - loss: 1.9015 - accuracy: 0.3700
# Epoch 5/10
# 13/13 [==============================] - 4s 336ms/step - loss: 1.9084 - accuracy: 0.3825
# Epoch 6/10
# 13/13 [==============================] - 4s 333ms/step - loss: 1.8562 - accuracy: 0.4000
# Epoch 7/10
# 13/13 [==============================] - 4s 340ms/step - loss: 1.8412 - accuracy: 0.3825
# Epoch 8/10
# 13/13 [==============================] - 5s 348ms/step - loss: 1.8133 - accuracy: 0.3950
# Epoch 9/10
# 13/13 [==============================] - 5s 349ms/step - loss: 1.8518 - accuracy: 0.3900
# Epoch 10/10
# 13/13 [==============================] - 4s 343ms/step - loss: 1.7783 - accuracy: 0.4325
# Score for fold 4: loss of 3.443770170211792; accuracy of 14.000000059604645%
# Model: "model_example"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Conv2D)              (None, 252, 934, 16)      416
#
#  elu (ELU)                   (None, 252, 934, 16)      0
#
#  dropout (Dropout)           (None, 252, 934, 16)      0
#
#  batch_normalization (Batch  (None, 252, 934, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 126, 467, 16)      0
#  D)
#
#  conv2d (Conv2D)             (None, 124, 465, 32)      4640
#
#  elu_1 (ELU)                 (None, 124, 465, 32)      0
#
#  dropout_1 (Dropout)         (None, 124, 465, 32)      0
#
#  batch_normalization_1 (Bat  (None, 124, 465, 32)      128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 233, 32)       0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 60, 231, 64)       18496
#
#  elu_2 (ELU)                 (None, 60, 231, 64)       0
#
#  dropout_2 (Dropout)         (None, 60, 231, 64)       0
#
#  batch_normalization_2 (Bat  (None, 60, 231, 64)       256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 58, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 56, 128)       73856
#
#  elu_3 (ELU)                 (None, 13, 56, 128)       0
#
#  dropout_3 (Dropout)         (None, 13, 56, 128)       0
#
#  batch_normalization_3 (Bat  (None, 13, 56, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 14, 128)        0
#  g2D)
#
#  reshape (Reshape)           (None, 56, 128)           0
#
#  gru (GRU)                   (None, 56, 24)            11088
#
#  gru_1 (GRU)                 (None, 24)                3600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  output (Dense)              (None, 19)                475
#
# =================================================================
# Total params: 113531 (443.48 KB)
# Trainable params: 113051 (441.61 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/10
# 13/13 [==============================] - 10s 343ms/step - loss: 1.8389 - accuracy: 0.3575
# Epoch 2/10
# 13/13 [==============================] - 5s 347ms/step - loss: 1.7403 - accuracy: 0.4200
# Epoch 3/10
# 13/13 [==============================] - 5s 348ms/step - loss: 1.7611 - accuracy: 0.4050
# Epoch 4/10
# 13/13 [==============================] - 4s 337ms/step - loss: 1.7469 - accuracy: 0.4150
# Epoch 5/10
# 13/13 [==============================] - 4s 334ms/step - loss: 1.6335 - accuracy: 0.4225
# Epoch 6/10
# 13/13 [==============================] - 4s 342ms/step - loss: 1.6739 - accuracy: 0.4225
# Epoch 7/10
# 13/13 [==============================] - 5s 348ms/step - loss: 1.6059 - accuracy: 0.4650
# Epoch 8/10
# 13/13 [==============================] - 5s 348ms/step - loss: 1.5953 - accuracy: 0.4775
# Epoch 9/10
# 13/13 [==============================] - 5s 349ms/step - loss: 1.4940 - accuracy: 0.5250
# Epoch 10/10
# 13/13 [==============================] - 5s 348ms/step - loss: 1.4877 - accuracy: 0.5000
# Score for fold 5: loss of 3.4594216346740723; accuracy of 14.000000059604645%

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 2.8474016189575195 - Accuracy: 14.000000059604645%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 2.9830520153045654 - Accuracy: 12.999999523162842%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 3.244926691055298 - Accuracy: 12.999999523162842%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 3.443770170211792 - Accuracy: 14.000000059604645%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 3.4594216346740723 - Accuracy: 14.000000059604645%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 13.599999845027924 (+- 0.4898982113583744)
# > Loss: 3.1957144260406496
# ------------------------------------------------------------------------
